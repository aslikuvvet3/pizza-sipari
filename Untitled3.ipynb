# %%
import csv
import datetime

with open("Menu.txt","w")as file.
      file.write("Lütfen Bir Pizza Tabani Seciniz:\n1"
      "1:Klasik Pizza\n"
      "2:Margarita\n "
      "3:Turk Pizza\n"
      "4Sade Pizza\n"
      "*sos seciniz:\n"
      "11: Zeytin\n"
      "12: Mantar\n"
      "13: Keci Peyniri\n"
      "14: Et\n"
      "15: Sogan:\n"
      "16: Misir:\n"
      "*Tesekkür Ederiz")

# %%
class Pizza
      def __init__(self):
        self.descripion = "Pizza"

      def get_description(self):
        return self.descripion

     def get_price(self):
       return 0

# %%
class  KlasikPizza(Pizza):
  def __init__(self):
    super(). __init__()
    self.description ="Klasik Pizza"
  def get_price(self):
    return 35


class MargaritaPizza(Pizza):
  def __init__(self):
    super(),__init__()
    self.descripion = "Margarita Pizza"
  def get_price:(self):
    return 30


class TurkPizza(Pizza):
  def __init__(self):
    super().__init__()
    self.description = "Turk Pizza"
  def get_price(self):
    return 42


class SadePizza(Pizza):
  def __init__(self):
    super().__init__()
    self.description = "Sade Pizza"
  def get_price(self):
    return 15

# %%
#decarator olustur
class PizzaDecorator(Pizza):
  def __init__(self,soslar):
    self.soslar = soslar

  def get_price(self):
    return self.soslar.get_price() + Pizza.get_price(self)

  def get_description(self):
    return get.soslar.get_description() + "," + + Pizza.get_description()

# %%
class Zeytin(PizzaDecorator):
  def __init__(self,soslar):
    self.soslar = soslar
    self.price = 2.0
    self.description = "Zeytin"

class Mantar(PizzaDecorator):
  def __init__(self):
    self.soslar = soslar
    self.price = 3.0
    self.description = "Mantar"

class KeciPeyniri(PizzaDecorator):
  def __init__(selfsoslar):
    self.soslar = soslar
    self.price= 4.0
    self description = "Keci Peyniri"

class Et(PizzaDecarator):
  def __init__(self):
    self.soslar = soslar
    self.price = 2.0
    self.description = "Et"

class Sogan(PizzaDecorator):
  def __init__(self):
    self.soslar = soslar
    self.price = 2.0
    self.description = "Sogan"

class Misir(PizzaDecorator):
  def __init__(self):
    self.soslar = soslar
    self.price = 3.0
    self.description = "Misir"

# %%
#main fonksiyon
def main():
  with open(Menu.txt","w") as menu:
    print(menu)


Pizza = ""
While Pizza =="":
          Pizza_secimi == input("Pizzanızı Seciniz:")
          if Pizza_secimi == "1":
            Pizza = KlasikPizza()
          elif Pizza_secimi == "2":
            Pizza = MargaritaPizza()
          elif Pizza_secimi == "3":
            Pizza = TurkPizza()
          elif Pizza_secimi == "4":
            Pizza = SadePizza()
          else:
            print("Lutfen Pizzanızı Seciniz")

soslar = ""
while soslar == "":
   Sos_secimi = input("Sosunuzu Seciniz:")
   if Sos_secimi == "11":
     Sos_secimi = Zeytin
   elif Sos_secimi == "12":
     Sos_secimi = Mantar
   elif Sos_secimi == "13":
     Sos_secimi = KeciPeyniri(Pizza)
    elif Sos_secimi == "14":
      Sos_secimi = Et
    elif Sos_secimi == "15":
      Sos_secimi = Sogan
    elif Sos_secimi == "16":
      Sos_secimi = Misir
    else:
      print("Lutfen Sosunuzu Seciniz")
      break

# %%
#siparis zamanı
order_time = datetime.datetime.now()

# %%
print("Siparis Detayi: ",Pizza.get_description())
print("Siparis Ucreti: ",Pizza.get_price,  "Dolar")

# %%
isim = input ("Lutfen Isminizi Giriniz: ")
tckimlik = input ("Lutfen Tc KImlık Numaranizi Giriniz: ")
while len(tc kimlik) !=11:
     print("Lutfen 11 haneli tc kimlik numaranızı giriniz")
     tckimlik = input ("Lutfen tc kimlik numaranızı giriniz: ")


KartNumarasi = input("Lutfen Kart Numarinizi Giriniz: ")
KartSifresi = input("Lütfen Kart Sifrenizi Giriniz: ")

while len (KartSifresi)!= 4:
    print ("Lutfen 4 Haneli Kart Sifrenizi Giriniz: ")
    KartSifresi input ("Lutfen Kart Sifrenizi Giriniz: ")

with open ('orders_database.csv', 'a')as orders:
  orders - csv.writer(orders, delimiter',')
  orders.writerow([isim,TcKimlik,KartNumarasi,KartSifresi, order,get_description(), time _of_order])
print("Siparisiniz Onaylandı.")
